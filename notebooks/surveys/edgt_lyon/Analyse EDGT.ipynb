# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
edgt_path = "../../../results/surveys/edgt_lyon"

# %%
df_legs = pd.read_parquet("%s/legs.parquet" % edgt_path)
gdf_trips = gpd.read_parquet("%s/trips.geoparquet" % edgt_path)
df_legs
# Out:
#        household_id  person_id  trip_id  leg_id mode transit_mode  mode_code
# 0                 0          0        0       0   pt          bus         31
# 1                 0          0        1       1   pt          bus         31
# 2                 0          1        2       2   pt          bus         31
# 3                 0          1        3       3   pt       subway         33
# 4                 0          1        3       4   pt         tram         32
# ...             ...        ...      ...     ...  ...          ...        ...
# 77309         16359      36561    99580   77309  car          car         21
# 77310         16359      36561    99581   77310  car          car         21
# 77311         16360      36562    99582   77311  car          car         21
# 77312         16360      36562    99583   77312  car          car         21
# 77313         16360      36562    99584   77313  car          car         21
#
# [77314 rows x 7 columns]

# %%
df_legs["mode"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='mode'>

# %%
df_legs.loc[df_legs["mode"] == "pt"].groupby("trip_id").size().value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: >
