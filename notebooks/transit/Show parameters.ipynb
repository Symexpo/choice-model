# %%
import pickle
import numpy as np

# %%
parameters_path = "../../results/transit/calibration.p"

# %%
# Load utilities
with open(parameters_path, "rb") as f:
    parameters = pickle.load(f)

    objectives = [item["objective"] for item in parameters if not np.isnan(item["objective"])]

    best_index = np.argmin(objectives)

    utilities = parameters[best_index]["utilities"]

# %%
utilities
# Out:
# {'rail_u_h': np.float64(-15.968564005921746),
#  'subway_u_h': -1.0,
#  'bus_u_h': np.float64(-4.48264547075693),
#  'tram_u_h': np.float64(-3.1139624402669024),
#  'other_u_h': np.float64(-4.48264547075693),
#  'wait_u_h': np.float64(-4.0120273523086984),
#  'walk_u_h': np.float64(-5.419472068373445),
#  'transfer_u': np.float64(-0.5591850122251055)}
