# %%
import pickle
import numpy as np

# %%
parameters_path = "../../results/transit/calibration.p"

# %%
# Load utilities
with open(parameters_path, "rb") as f:
    parameters = pickle.load(f)

    objectives = [item["objective"] for item in parameters]
    best_index = np.argmin(objectives)

    utilities = parameters[best_index]["utilities"]

# %%
utilities
# Out:
# {'rail_u_h': np.float64(-4.972996494437551),
#  'subway_u_h': -1.0,
#  'bus_u_h': np.float64(-4.37485756983825),
#  'tram_u_h': np.float64(-2.5317829376283885),
#  'other_u_h': np.float64(-4.37485756983825),
#  'wait_u_h': np.float64(-0.044797000340805665),
#  'walk_u_h': np.float64(-4.107056522304296),
#  'transfer_u': np.float64(-8.186473859826691e-05)}
